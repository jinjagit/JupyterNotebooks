# %% [markdown]
# Tutorial on basics of Jupyter Notebook: [DataCamp Jupyter Tutorial](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook?utm_source=adwords_ppc&utm_campaignid=1001535064&utm_adgroupid=48949243189&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=236326164852&utm_targetid=dsa-379899700955&utm_loc_interest_ms=&utm_loc_physical_ms=1001773&gclid=CjwKCAiA-9rTBRBNEiwAt0Znw2Znh7HZTPwFpQ-S8cZJlHObiIxRLWjkFatqqCGQvxdmHnSp0ijP1RoCPh4QAvD_BwE)
#
# [Online 'live' version](https://mybinder.org/v2/gh/jinjagit/JupyterNotebooks/master?filepath=tutorial.ipynb
# ) (or better, install Jupyter and download / run this file)

# %% [markdown]
# **NOTE: The following code should be run before other code in this notebook** (imports necessary libraries):

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ipywidgets import interact,FloatSlider,IntSlider

print("libraries imported")  # <- run until output prints (may need to run 2x, or more. Don't know why.)
# Out:
# libraries imported

# %% [markdown]
# DataFrames:

# %%
df = pd.DataFrame(data=np.array([[1, 2, 3], [4, 5, 6]], dtype = int), columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# LaTex math, in markdown cell;

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %% [markdown]
# Note: Aside from being a great way to include math notation, LaTex is also (theoretically) Turing complete!

# %% [markdown]
# Listing the 'magic functions' available;

# %%
# %lsmagic

# %%
# Retrieving documentation on the alias_magic command
?%alias_magic

# %% [markdown]
# ipywidgets (from: [StackOverflowSineWave](https://stackoverflow.com/questions/44329068/jupyter-notebook-interactive-plot-with-widgets)):
#
# E.g. Interactive sine wave plot (nope, I don't understand most of this code, yet):

# %%
# %matplotlib notebook

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw()
    plt.show()

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="432">
# A Jupyter Widget
